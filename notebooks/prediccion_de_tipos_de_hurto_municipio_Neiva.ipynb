# %% [markdown]
# #Pediccion de Tipos de Hurto Municipio Neiva
# Se espera desarrollar un modelo de clasificación preciso y útil que pueda predecir el tipo de hurto en el municipio Neiva. Este modelo podría utilizarse para identificar áreas de alto riesgo, implementar medidas preventivas específicas y mejorar la seguridad pública en el municipio.
#
# ##Origen de los Datos:
# Los datos utilizados en este proyecto fueron obtenidos de la página de datos abiertos de Colombia, una iniciativa del gobierno colombiano para proporcionar acceso público a conjuntos de datos de interés general. La URL de donde se obtuvieron los datos es la siguiente: ['https://www.datos.gov.co/Estad-sticas-Nacionales/Hurtos-del-municipio-de-Neiva/ej25-5qcr/about_data?fbclid=IwAR1weDRxKxxOHnnEWodsRH0llK4s1mxtkc5_YjO6XrIayZCmQGrG_pod4dc#'].
#
# ##Descripción de los Datos:
# Los datos consisten en un conjunto de registros de hurtos ocurridos en un municipio Neiva durante un período de tiempo determinado. Cada registro contiene información detallada sobre el incidente de hurto, incluyendo la fecha y hora del hurto, la ubicación exacta, el tipo de propiedad robada y otras características relevantes.
#
# ##Uso de los Datos en el Proyecto:
# Los datos obtenidos de la página de datos abiertos de Colombia serán utilizados en este proyecto para analizar y predecir los diferentes tipos de hurto que ocurren en el municipio. El objetivo es desarrollar un modelo de clasificación que pueda predecir el tipo de hurto en función de diversas características asociadas con cada incidente, como la ubicación, la hora del día, el día de la semana, etc

# %%
import pandas as pd
url='https://github.com/miguelreal90/prediccion_tipos_de_Hurto_municipio_Neiva/raw/main/Hurtos_2021-2022_Corte_a_DICIEMBRE.xlsx'
df=pd.read_excel(url)
df.head()
# Out:
#   Fecha y Hora  del hecho Fecha del hecho Dia de la Semana  \
# 0     2022-01-01 03:30:00      2022-01-01           sábado
# 1     2022-01-02 00:00:00      2022-01-02          domingo
# 2     2022-01-02 18:00:00      2022-01-02          domingo
# 3     2022-01-02 18:00:00      2022-01-02          domingo
# 4     2022-01-02 19:30:00      2022-01-02          domingo
#
#   Hora del hecho (HH:MM)     Genero Comuna              Modalidad  \
# 0               03:30:00  Masculino      6  Factor de oportunidad
# 1               00:00:00   Femenino      3               Raponazo
# 2               18:00:00  Masculino      6                 Atraco
# 3               18:00:00  Masculino      7                 Atraco
# 4               19:30:00  Masculino      5                 Atraco
#
#            Arma/medio         Móvil agresor          Móvil víctima Edad  \
# 0  Sin empleo de arma                 A pie     Conductor vehículo   38
# 1  Sin empleo de arma                 A pie                  A pie   45
# 2       Arma de fuego  Pasajero motocicleta                  A pie   73
# 3       Arma de fuego  Pasajero motocicleta     Conductor vehículo   53
# 4         Arma blanca  Pasajero motocicleta  Conductor motocicleta   64
#
#   Descripcion Conducta
# 0     Hurto a personas
# 1     Hurto a personas
# 2     Hurto a personas
# 3     Hurto a personas
# 4     Hurto a personas

# %%
#Buscamos valores nulos
df.isnull().sum()
# Out:
# Fecha y Hora  del hecho    0
# Fecha del hecho            0
# Dia de la Semana           0
# Hora del hecho (HH:MM)     0
# Genero                     0
# Comuna                     0
# Modalidad                  0
# Arma/medio                 0
# Móvil agresor              0
# Móvil víctima              0
# Edad                       0
# Descripcion Conducta       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 41

# %%
df.drop_duplicates()
# Out:
#      Fecha y Hora  del hecho Fecha del hecho Dia de la Semana  \
# 0        2022-01-01 03:30:00      2022-01-01           sábado
# 1        2022-01-02 00:00:00      2022-01-02          domingo
# 2        2022-01-02 18:00:00      2022-01-02          domingo
# 3        2022-01-02 18:00:00      2022-01-02          domingo
# 4        2022-01-02 19:30:00      2022-01-02          domingo
# ...                      ...             ...              ...
# 3701     2022-12-29 16:30:00      2022-12-29           jueves
# 3702     2022-12-29 02:00:00      2022-12-29           jueves
# 3703     2022-12-30 05:40:00      2022-12-30          viernes
# 3704     2022-12-30 22:00:00      2022-12-30          viernes
# 3705     2022-12-30 22:00:00      2022-12-30          viernes
#
#      Hora del hecho (HH:MM)     Genero Comuna              Modalidad  \
# 0                  03:30:00  Masculino      6  Factor de oportunidad
# 1                  00:00:00   Femenino      3               Raponazo
# 2                  18:00:00  Masculino      6                 Atraco
# 3                  18:00:00  Masculino      7                 Atraco
# 4                  19:30:00  Masculino      5                 Atraco
# ...                     ...        ...    ...                    ...
# 3701               16:30:00  Masculino     10                 Atraco
# 3702               02:00:00  Masculino      9                 Atraco
# 3703               05:40:00  Masculino      2  Factor de oportunidad
# 3704               22:00:00   Femenino      1                 Atraco
# 3705               22:00:00  Masculino      2  Factor de oportunidad
#
#               Arma/medio         Móvil agresor          Móvil víctima Edad  \
# 0     Sin empleo de arma                 A pie     Conductor vehículo   38
# 1     Sin empleo de arma                 A pie                  A pie   45
# 2          Arma de fuego  Pasajero motocicleta                  A pie   73
# 3          Arma de fuego  Pasajero motocicleta     Conductor vehículo   53
# 4            Arma blanca  Pasajero motocicleta  Conductor motocicleta   64
# ...                  ...                   ...                    ...  ...
# 3701       Arma de Fuego                 A pie                  A pie   76
# 3702         Arma Blanca                 A pie                  A pie   33
# 3703  Sin empleo de arma                 A pie                  A pie   30
# 3704       Arma de Fuego  Pasajero motocicleta  Conductor motocicleta   30
# 3705  Sin empleo de arma                 A pie  Conductor motocicleta   41
#
#       Descripcion Conducta
# 0         Hurto a personas
# 1         Hurto a personas
# 2         Hurto a personas
# 3         Hurto a personas
# 4         Hurto a personas
# ...                    ...
# 3701  Hurto a motocicletas
# 3702  Hurto a motocicletas
# 3703  Hurto a motocicletas
# 3704  Hurto a motocicletas
# 3705  Hurto a motocicletas
#
# [3665 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Fecha y Hora  del hecho', 'Fecha del hecho', 'Dia de la Semana',
#        'Hora del hecho (HH:MM)', 'Genero', 'Comuna', 'Modalidad', 'Arma/medio',
#        'Móvil agresor', 'Móvil víctima', 'Edad', 'Descripcion Conducta'],
#       dtype='object')

# %%
# borramos la columna 'Fecha y Hora del hecho'
df.drop('Fecha y Hora  del hecho', axis=1, inplace=True)
df.head()
# Out:
#   Fecha del hecho Dia de la Semana Hora del hecho (HH:MM)     Genero Comuna  \
# 0      2022-01-01           sábado               03:30:00  Masculino      6
# 1      2022-01-02          domingo               00:00:00   Femenino      3
# 2      2022-01-02          domingo               18:00:00  Masculino      6
# 3      2022-01-02          domingo               18:00:00  Masculino      7
# 4      2022-01-02          domingo               19:30:00  Masculino      5
#
#                Modalidad          Arma/medio         Móvil agresor  \
# 0  Factor de oportunidad  Sin empleo de arma                 A pie
# 1               Raponazo  Sin empleo de arma                 A pie
# 2                 Atraco       Arma de fuego  Pasajero motocicleta
# 3                 Atraco       Arma de fuego  Pasajero motocicleta
# 4                 Atraco         Arma blanca  Pasajero motocicleta
#
#            Móvil víctima Edad Descripcion Conducta
# 0     Conductor vehículo   38     Hurto a personas
# 1                  A pie   45     Hurto a personas
# 2                  A pie   73     Hurto a personas
# 3     Conductor vehículo   53     Hurto a personas
# 4  Conductor motocicleta   64     Hurto a personas

# %%
conteo_modalidad = df['Modalidad'].value_counts()

print(conteo_modalidad)
# Out:
# Atraco                                     1671
# No reportada                                536
# Raponazo                                    477
# Factor de oportunidad                       476
# Halado                                      179
# Violacion de cerradura                       94
# Violación de cerradura                       48
# Ventosa                                      46
# Engaño                                       37
# Llave maestra                                24
# Factor oportunidad                           19
# Rompimiento de vidrio                        18
# Vandalismo                                   18
# Mechero                                      11
# Cosquilleo                                    8
# Factor de opotunidad                          5
# Fleteo                                        5
# Rompiiento de vidrio                          4
# Bataleo                                       4
# Escopolamina                                  3
# Descuelgue de mercancía                       3
# Descuelgue de mercancia                       2
# Suplantación                                  2
# Atraco                                        2
# Mechero                                       2
# Uso de sustancias toxicas                     2
# COSQUILLEO                                    1
# USO SUSTANCIAS TOXICAS / ESCOPOLAMINADO       1
# Sustracción en movimiento                     1
# -                                             1
# Sin dato                                      1
# Lave maestra                                  1
# Violcion de caja fuerte                       1
# Sustraccion en movimiento                     1
# Rompimiento pared                             1
# Supuesto ganador de loteria                   1
# Name: Modalidad, dtype: int64

# %% [markdown]
# Conteo y exploracion de las variables

# %%
def mostrar_conteo_valores(dataframe):
    for columna in dataframe.columns:
        conteo_valores = dataframe[columna].value_counts()
        print(f"Columna: {columna}")
        print(conteo_valores)
        print("------")
mostrar_conteo_valores(df)
# Out:
# Columna: Fecha del hecho
# 2022-03-18    27
# 2022-10-01    26
# 2022-12-17    26
# 2022-03-01    24
# 2022-12-02    24
#               ..
# 2022-04-26     2
# 2022-09-11     1
# 2022-07-30     1
# 2022-04-17     1
# 2022-01-01     1
# Name: Fecha del hecho, Length: 364, dtype: int64
# ------
# Columna: Dia de la Semana
# viernes      623
# sábado       574
# miércoles    541
# martes       539
# jueves       525
# lunes        513
# domingo      391
# Name: Dia de la Semana, dtype: int64
# ------
# Columna: Hora del hecho (HH:MM)
# No reportada    200
# 20:00:00         82
# 19:30:00         73
# 20:30:00         72
# 19:00:00         70
#                ...
# 16:15             1
# 19:50             1
# 05:33:00          1
# 08:55:00          1
# 16:41:00          1
# Name: Hora del hecho (HH:MM), Length: 514, dtype: int64
# ------
# Columna: Genero
# Masculino    2048
# Femenino     1386
# No aplica     211
# Sin dato       61
# Name: Genero, dtype: int64
# ------
# Columna: Comuna
# 1                   606
# 6                   530
# 4                   442
# 2                   345
# 5                   241
# 3                   230
# 10                  208
# 7                   162
# 1                   157
# 9                   131
# 8                   100
# 6                    93
# 4                    83
# 3                    54
# 2                    53
# 10                   43
# 7                    36
# 5                    33
# Veredas de Neiva     27
# 9                    23
# El Caguán            22
# 8                    21
# No reportada         21
# Fortalecillas        14
# Sin dato             12
# Vegalarga             7
# El caguán             3
# Río Las Ceibas        3
# Guacirco              2
# VEREDAS DE NEIVA      2
# Río ceibas            1
# El Caguán             1
# Name: Comuna, dtype: int64
# ------
# Columna: Modalidad
# Atraco                                     1671
# No reportada                                536
# Raponazo                                    477
# Factor de oportunidad                       476
# Halado                                      179
# Violacion de cerradura                       94
# Violación de cerradura                       48
# Ventosa                                      46
# Engaño                                       37
# Llave maestra                                24
# Factor oportunidad                           19
# Rompimiento de vidrio                        18
# Vandalismo                                   18
# Mechero                                      11
# Cosquilleo                                    8
# Factor de opotunidad                          5
# Fleteo                                        5
# Rompiiento de vidrio                          4
# Bataleo                                       4
# Escopolamina                                  3
# Descuelgue de mercancía                       3
# Descuelgue de mercancia                       2
# Suplantación                                  2
# Atraco                                        2
# Mechero                                       2
# Uso de sustancias toxicas                     2
# COSQUILLEO                                    1
# USO SUSTANCIAS TOXICAS / ESCOPOLAMINADO       1
# Sustracción en movimiento                     1
# -                                             1
# Sin dato                                      1
# Lave maestra                                  1
# Violcion de caja fuerte                       1
# Sustraccion en movimiento                     1
# Rompimiento pared                             1
# Supuesto ganador de loteria                   1
# Name: Modalidad, dtype: int64
# ------
# Columna: Arma/medio
# Sin empleo de arma    1550
# Arma de fuego          861
# Arma de Fuego          473
# Arma blanca            388
# Arma Blanca            168
# Palanca                111
# Contundente            105
# Llave maestra           19
# Sin dato                11
# Escopolamina             8
# Arma de fuego            6
# No reportada             4
# Arma blanca              1
# ESCOPOLAMINA             1
# Name: Arma/medio, dtype: int64
# ------
# Columna: Móvil agresor
# Pasajero motocicleta     1843
# A pie                    1395
# Pasajero motocicleta      291
# Conductor motocicleta     135
# Bicicleta                  11
# Pasajero bus                8
# Conductor taxi              6
# Conductor vehiculo          3
# Pasajero vehiculo           3
# Condutor Motocicleta        3
# Bicilceta                   2
# Conductor vehículo          2
# Pasajero taxi               1
# Pasajero vehículo           1
# No reportada                1
# PASAJERO METRO              1
# Name: Móvil agresor, dtype: int64
# ------
# Columna: Móvil víctima
# A pie                     2629
# Conductor motocicleta      662
# Conductor motocicleta      112
# Conductor vehiculo          87
# Conductor vehículo          69
# Pasajero motocicleta        66
# Bicicleta                   26
# Pasajero taxi               13
# Pasajero bus                12
# Pasajero motocicleta        10
# Pasajero vehículo            8
# CONDUCTOR BUS                2
# Condutor Motocicleta         2
# Pasajero vehiculo            2
# Bicilceta                    2
# Motocicleta                  2
# Conductor de vehiculo        1
# Conductor taxi               1
# Name: Móvil víctima, dtype: int64
# ------
# Columna: Edad
# No aplica       545
# Sin dato        165
# 27              100
# No reportada     96
# 29               85
#                ...
# 6                 1
# 61 o más          1
# 14                1
# 71                1
# 77                1
# Name: Edad, Length: 134, dtype: int64
# ------
# Columna: Descripcion Conducta
# Hurto a personas        2515
# Hurto a motocicletas     436
# Hurto a residencias      404
# Hurto a comercio         271
# Hurto de motos            69
# Hurto a automotores       11
# Name: Descripcion Conducta, dtype: int64
# ------

# %% [markdown]
# vamos que varios valores se repiten y los cuenta como diferentes, trabajaremos en eso

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
from unidecode import unidecode

# Suponiendo que 'df' es tu DataFrame

# Define una función para normalizar una cadena de texto (convertir a minúsculas, eliminar acentos y espacios en blanco al principio y al final)
def normalizar_texto(texto):
    return unidecode(str(texto).lower().strip())

# Aplica la función a cada celda del DataFrame que sea de tipo objeto (texto)
df = df.applymap(normalizar_texto)

# Ahora todas las cadenas de texto en el DataFrame 'df' están normalizadas (minúsculas, sin acentos y sin espacios en blanco al principio y al final)

# %%
mostrar_conteo_valores(df)
# Out:
# Columna: Fecha del hecho
# 2022-03-18 00:00:00    27
# 2022-10-01 00:00:00    26
# 2022-12-17 00:00:00    26
# 2022-03-01 00:00:00    24
# 2022-12-02 00:00:00    24
#                        ..
# 2022-04-26 00:00:00     2
# 2022-09-11 00:00:00     1
# 2022-07-30 00:00:00     1
# 2022-04-17 00:00:00     1
# 2022-01-01 00:00:00     1
# Name: Fecha del hecho, Length: 364, dtype: int64
# ------
# Columna: Dia de la Semana
# viernes      623
# sabado       574
# miercoles    541
# martes       539
# jueves       525
# lunes        513
# domingo      391
# Name: Dia de la Semana, dtype: int64
# ------
# Columna: Hora del hecho (HH:MM)
# no reportada    200
# 20:00:00         82
# 19:30:00         73
# 20:30:00         72
# 19:00:00         70
#                ...
# 16:15             1
# 19:50             1
# 05:33:00          1
# 08:55:00          1
# 16:41:00          1
# Name: Hora del hecho (HH:MM), Length: 514, dtype: int64
# ------
# Columna: Genero
# masculino    2048
# femenino     1386
# no aplica     211
# sin dato       61
# Name: Genero, dtype: int64
# ------
# Columna: Comuna
# 1                   763
# 6                   623
# 4                   525
# 2                   398
# 3                   284
# 5                   274
# 10                  251
# 7                   198
# 9                   154
# 8                   121
# veredas de neiva     29
# el caguan            26
# no reportada         21
# fortalecillas        14
# sin dato             12
# vegalarga             7
# rio las ceibas        3
# guacirco              2
# rio ceibas            1
# Name: Comuna, dtype: int64
# ------
# Columna: Modalidad
# atraco                                     1673
# no reportada                                536
# raponazo                                    477
# factor de oportunidad                       476
# halado                                      179
# violacion de cerradura                      142
# ventosa                                      46
# engano                                       37
# llave maestra                                24
# factor oportunidad                           19
# rompimiento de vidrio                        18
# vandalismo                                   18
# mechero                                      13
# cosquilleo                                    9
# descuelgue de mercancia                       5
# fleteo                                        5
# factor de opotunidad                          5
# bataleo                                       4
# rompiiento de vidrio                          4
# escopolamina                                  3
# sustraccion en movimiento                     2
# uso de sustancias toxicas                     2
# suplantacion                                  2
# sin dato                                      1
# supuesto ganador de loteria                   1
# lave maestra                                  1
# uso sustancias toxicas / escopolaminado       1
# -                                             1
# violcion de caja fuerte                       1
# rompimiento pared                             1
# Name: Modalidad, dtype: int64
# ------
# Columna: Arma/medio
# sin empleo de arma    1550
# arma de fuego         1340
# arma blanca            557
# palanca                111
# contundente            105
# llave maestra           19
# sin dato                11
# escopolamina             9
# no reportada             4
# Name: Arma/medio, dtype: int64
# ------
# Columna: Móvil agresor
# pasajero motocicleta     2134
# a pie                    1395
# conductor motocicleta     135
# bicicleta                  11
# pasajero bus                8
# conductor taxi              6
# conductor vehiculo          5
# pasajero vehiculo           4
# condutor motocicleta        3
# bicilceta                   2
# pasajero taxi               1
# no reportada                1
# pasajero metro              1
# Name: Móvil agresor, dtype: int64
# ------
# Columna: Móvil víctima
# a pie                    2629
# conductor motocicleta     774
# conductor vehiculo        156
# pasajero motocicleta       76
# bicicleta                  26
# pasajero taxi              13
# pasajero bus               12
# pasajero vehiculo          10
# bicilceta                   2
# condutor motocicleta        2
# conductor bus               2
# motocicleta                 2
# conductor de vehiculo       1
# conductor taxi              1
# Name: Móvil víctima, dtype: int64
# ------
# Columna: Edad
# no aplica    545
# sin dato     165
# 27           133
# 24           120
# 29           117
#             ...
# 12             1
# 77             1
# 82             1
# 80             1
# 5              1
# Name: Edad, Length: 74, dtype: int64
# ------
# Columna: Descripcion Conducta
# hurto a personas        2515
# hurto a motocicletas     436
# hurto a residencias      404
# hurto a comercio         271
# hurto de motos            69
# hurto a automotores       11
# Name: Descripcion Conducta, dtype: int64
# ------

# %% [markdown]
# borramos la columna edad por la cantidad de datos vacios vacios y falta de informacion

# %%
df.head()
# Out:
#        Fecha del hecho Dia de la Semana Hora del hecho (HH:MM)     Genero  \
# 0  2022-01-01 00:00:00           sabado               03:30:00  masculino
# 1  2022-01-02 00:00:00          domingo               00:00:00   femenino
# 2  2022-01-02 00:00:00          domingo               18:00:00  masculino
# 3  2022-01-02 00:00:00          domingo               18:00:00  masculino
# 4  2022-01-02 00:00:00          domingo               19:30:00  masculino
#
#   Comuna              Modalidad          Arma/medio         Móvil agresor  \
# 0      6  factor de oportunidad  sin empleo de arma                 a pie
# 1      3               raponazo  sin empleo de arma                 a pie
# 2      6                 atraco       arma de fuego  pasajero motocicleta
# 3      7                 atraco       arma de fuego  pasajero motocicleta
# 4      5                 atraco         arma blanca  pasajero motocicleta
#
#            Móvil víctima Edad Descripcion Conducta
# 0     conductor vehiculo   38     hurto a personas
# 1                  a pie   45     hurto a personas
# 2                  a pie   73     hurto a personas
# 3     conductor vehiculo   53     hurto a personas
# 4  conductor motocicleta   64     hurto a personas
